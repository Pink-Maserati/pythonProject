# %%
import re

with open('./game_short.txt', 'r') as f:
    comment = f.readline()
print(comment)

# 尝试将一行替换成多行
temp_comment = re.sub('==', '\n', comment)
print(temp_comment)

print(type(temp_comment))

print(re.split('==',comment)[0])

print(re.split('==',comment)[0].split("::"))


temp = re.split('==', comment)[0]
print(temp)
print(re.sub('\[\'allstar([0-9]{1,2})\'\]', r'*** \1 ***', comment))


# 分数
star = re.sub('\[\'.*?allstar([0-9]{1,2})\'\].*?==', r'\1,', comment)
print(star)
star_list = re.split(',', star)
star_list.pop()
print(star_list)

#评论
comment_list = []
comment_line = re.split(r'::', comment)
for line in comment_line:
    if (re.search('==', line)):
        comment_txt = re.split('==', line)[0]
        # 写入列表
        comment_list.append(re.sub('\[\'(.*)\'\]', r'\1', comment_txt))
print(comment_list)



#统计重复分值个数
from collections import Counter
result=Counter(star_list)
print(result)
result['50'] = 0

list=[]
for i in sorted(result):
    list.append(result[i])

print(list)



#饼图
from pyecharts.charts import Pie

attr = ["0分", "10分", "20分", "30分", "40分", "50分"]
values = [result[i] for i in sorted(result)]
pie = Pie()

pie.add("", [z for z in zip(attr, values)])
pie.render("mypie.html")
# Out:
# ['yuiii🐰']::['allstar0']::['仿生人会梦见电子鸽吗']==['肖达明的副本']::['allstar40']::['那个把绀碧大厦当成妓院的人，你玩过游戏吗？']==['ZZ风起时']::['allstar10']::['修改为一星，为了基努不退款算对蠢驴客气了']==['|Ψ〉']::['allstar10']::['想了想不知道说什么，从技术到美学到设计，似乎在“勉强做成一个游戏”的范围内，在任何细微的角度去看都已经触及了最下限（完美的球对称性）。哪怕是这几年最令人发指的《宝可梦剑盾》，与之相比都过分可爱了起来。而有些玩家，则永远保持着不当韭菜天理难容的宽容。']==['Cuckoldoggy']::['allstar10']::['这垃圾优化和满天的bug也敢拿出来卖？ 今年游戏界第二起消费欺诈行为']==['nesta']::['allstar10']::['半成品拿来卖nm呢。bug不说，就当以后能修复。关键是宣传中许多东西根本没实现。']==['张小段']::['allstar10']::['其他游戏公司出bug：垃圾游戏垃圾公司，滚吧，垃圾公司。\nCDPR 出bug：人不够没做完没办法，原谅它好吗？\n其他游戏公司虚假宣传：垃圾公司退款，再也不买再也不预购。祝游戏公司倒闭。\nCDPR虚假宣传：不跳票我们玩到就不错了，虚假宣传，不得已罢了。\n其他公司游戏打折：早知道不买了谁买谁上当。\nCDPR游戏打折：波兰蠢驴年度良心，我就让你赚钱。我们CDPR真是太厉害了，让我们在2020年年末玩到2077年的游戏。\nCDPR 孝子：你说他是fps？它不早就告诉你是RPG了。就知道跟风黑游戏，我看你都没玩过吧？又不是不会更新了，哪有什么虚假宣传，没做完罢了。开放世界？做不完没办法，毕竟才做了八年。\n我：孝死了。']==['ATReeves']::['allstar0']::['越来越多的证据表明，这款游戏的发售日期并不是2077年。']==['Cole']::['allstar40']::['  断断续续玩了三个月终于通了，总的来说感觉还是差点意思。兴许是刚开始抱着太高的期望再加上开头几天冲太猛了，后面一直没有什么动力继续玩下去。这两天终于在寒假倒计时的时候把主线支线都通了。其实对于关键的几个人物印象都还是比较深刻的，人物塑造的也都还不错。在最后每个人道别的时候，让我还是想再回去看他们一次，还是很爱他们每一个人。\n  总之希望后续dlc能好好做，毕竟当时抱了挺大的期望，还是希望夜之城能吸引我重新回到这座城市。\n  Goodbye, Night City and all my friends.\n  Hope to see you again.']==['Akira']::['allstar30']::['很快啊']==['星子滑落夜空']::['allstar0']::['仿生人会梦到赛博朋克2077吗？']==['司马农批']::['allstar0']::['b社有天赋？是教子有方吗？']==['SquareOfSlow']::['allstar0']::['我最喜欢这游戏的一点就是你如果不自己玩的话，在国内网络上几乎完全看不到这个游戏的真实模样是什么~']==['弹道学凝胶假人']::['allstar30']::['期望越高，失望越大，等了8年就等来这\n除了画面和bug（这两点也不用细说了大家都有体验）；游戏性，沉浸感方面的问题更让人担忧，比如：\nNPC开车只会走直线，你把车停马路中间整条路就会堵死，因为NPC不会绕开，\n买义体改造连个动画都没有，跟在早点铺买包子没区别，\n说到早点铺，夜之城路边的商贩全都不能互动，\n阿sir是在玩家出现犯罪行为后直接生成的，过一会又会直接消失，\n当街开一枪，方圆两个街区所有路人整齐划一蹲下抱头等等等等…\n这就是CDPR口口声声宣传的“迄今为止沉浸感最强的开放世界”？\n目前感觉只有写好剧本的任务表现尚可，free roaming完全没意思\n索尼开始给2077数字版提供退款了，我已退款，游戏界曾经我最信任的开发商在我心里死了']==['HendersonYy']::['allstar10']::['官方推荐配置1080p只要1066+16g，好家伙进去开全低30帧。诈骗呢？你家推荐配置是30帧玩游戏的？说清楚我就不会买。']==['流水不争先']::['allstar10']::['还是血战上海滩好玩']==['糕等数学']::['allstar0']::['我倒要看看到底有多好玩？']==['Neltharion.K']::['allstar10']::['2020年游戏圈最大骗局，索尼下架，股票狂跌，大快人心！明明知道主机平台问题严重，在发售最后一天还在装模作样，宣发的时候都是PC演示，主机什么德性只有cdpr自己清楚！然后就满嘴谎话欺骗玩家，如果你们当时再把主机运行的承诺说的具体一点，就要被起诉欺诈了知道么']==['陈建宇Dede']::['allstar20']::['是诈骗吧！bug多到不想打开 我就说我在酒吧下面坐了半天没等到朱迪吧 怎么了 2077年谈个恋爱还这么麻烦吗']==['叶湫忆']::['allstar0']::['2077年，媒体公布最受期待游戏:《赛博朋克2077》《对马岛之鬼》《死亡搁浅》《骑砍2》《上古卷轴6》《半条命3》']==
# ['yuiii🐰']::['allstar0']::['仿生人会梦见电子鸽吗']
# ['肖达明的副本']::['allstar40']::['那个把绀碧大厦当成妓院的人，你玩过游戏吗？']
# ['ZZ风起时']::['allstar10']::['修改为一星，为了基努不退款算对蠢驴客气了']
# ['|Ψ〉']::['allstar10']::['想了想不知道说什么，从技术到美学到设计，似乎在“勉强做成一个游戏”的范围内，在任何细微的角度去看都已经触及了最下限（完美的球对称性）。哪怕是这几年最令人发指的《宝可梦剑盾》，与之相比都过分可爱了起来。而有些玩家，则永远保持着不当韭菜天理难容的宽容。']
# ['Cuckoldoggy']::['allstar10']::['这垃圾优化和满天的bug也敢拿出来卖？ 今年游戏界第二起消费欺诈行为']
# ['nesta']::['allstar10']::['半成品拿来卖nm呢。bug不说，就当以后能修复。关键是宣传中许多东西根本没实现。']
# ['张小段']::['allstar10']::['其他游戏公司出bug：垃圾游戏垃圾公司，滚吧，垃圾公司。\nCDPR 出bug：人不够没做完没办法，原谅它好吗？\n其他游戏公司虚假宣传：垃圾公司退款，再也不买再也不预购。祝游戏公司倒闭。\nCDPR虚假宣传：不跳票我们玩到就不错了，虚假宣传，不得已罢了。\n其他公司游戏打折：早知道不买了谁买谁上当。\nCDPR游戏打折：波兰蠢驴年度良心，我就让你赚钱。我们CDPR真是太厉害了，让我们在2020年年末玩到2077年的游戏。\nCDPR 孝子：你说他是fps？它不早就告诉你是RPG了。就知道跟风黑游戏，我看你都没玩过吧？又不是不会更新了，哪有什么虚假宣传，没做完罢了。开放世界？做不完没办法，毕竟才做了八年。\n我：孝死了。']
# ['ATReeves']::['allstar0']::['越来越多的证据表明，这款游戏的发售日期并不是2077年。']
# ['Cole']::['allstar40']::['  断断续续玩了三个月终于通了，总的来说感觉还是差点意思。兴许是刚开始抱着太高的期望再加上开头几天冲太猛了，后面一直没有什么动力继续玩下去。这两天终于在寒假倒计时的时候把主线支线都通了。其实对于关键的几个人物印象都还是比较深刻的，人物塑造的也都还不错。在最后每个人道别的时候，让我还是想再回去看他们一次，还是很爱他们每一个人。\n  总之希望后续dlc能好好做，毕竟当时抱了挺大的期望，还是希望夜之城能吸引我重新回到这座城市。\n  Goodbye, Night City and all my friends.\n  Hope to see you again.']
# ['Akira']::['allstar30']::['很快啊']
# ['星子滑落夜空']::['allstar0']::['仿生人会梦到赛博朋克2077吗？']
# ['司马农批']::['allstar0']::['b社有天赋？是教子有方吗？']
# ['SquareOfSlow']::['allstar0']::['我最喜欢这游戏的一点就是你如果不自己玩的话，在国内网络上几乎完全看不到这个游戏的真实模样是什么~']
# ['弹道学凝胶假人']::['allstar30']::['期望越高，失望越大，等了8年就等来这\n除了画面和bug（这两点也不用细说了大家都有体验）；游戏性，沉浸感方面的问题更让人担忧，比如：\nNPC开车只会走直线，你把车停马路中间整条路就会堵死，因为NPC不会绕开，\n买义体改造连个动画都没有，跟在早点铺买包子没区别，\n说到早点铺，夜之城路边的商贩全都不能互动，\n阿sir是在玩家出现犯罪行为后直接生成的，过一会又会直接消失，\n当街开一枪，方圆两个街区所有路人整齐划一蹲下抱头等等等等…\n这就是CDPR口口声声宣传的“迄今为止沉浸感最强的开放世界”？\n目前感觉只有写好剧本的任务表现尚可，free roaming完全没意思\n索尼开始给2077数字版提供退款了，我已退款，游戏界曾经我最信任的开发商在我心里死了']
# ['HendersonYy']::['allstar10']::['官方推荐配置1080p只要1066+16g，好家伙进去开全低30帧。诈骗呢？你家推荐配置是30帧玩游戏的？说清楚我就不会买。']
# ['流水不争先']::['allstar10']::['还是血战上海滩好玩']
# ['糕等数学']::['allstar0']::['我倒要看看到底有多好玩？']
# ['Neltharion.K']::['allstar10']::['2020年游戏圈最大骗局，索尼下架，股票狂跌，大快人心！明明知道主机平台问题严重，在发售最后一天还在装模作样，宣发的时候都是PC演示，主机什么德性只有cdpr自己清楚！然后就满嘴谎话欺骗玩家，如果你们当时再把主机运行的承诺说的具体一点，就要被起诉欺诈了知道么']
# ['陈建宇Dede']::['allstar20']::['是诈骗吧！bug多到不想打开 我就说我在酒吧下面坐了半天没等到朱迪吧 怎么了 2077年谈个恋爱还这么麻烦吗']
# ['叶湫忆']::['allstar0']::['2077年，媒体公布最受期待游戏:《赛博朋克2077》《对马岛之鬼》《死亡搁浅》《骑砍2》《上古卷轴6》《半条命3》']
#
# <class 'str'>
# ['yuiii🐰']::['allstar0']::['仿生人会梦见电子鸽吗']
# ["['yuiii🐰']", "['allstar0']", "['仿生人会梦见电子鸽吗']"]
# ['yuiii🐰']::['allstar0']::['仿生人会梦见电子鸽吗']
# ['yuiii🐰']::*** 0 ***::['仿生人会梦见电子鸽吗']==['肖达明的副本']::*** 40 ***::['那个把绀碧大厦当成妓院的人，你玩过游戏吗？']==['ZZ风起时']::*** 10 ***::['修改为一星，为了基努不退款算对蠢驴客气了']==['|Ψ〉']::*** 10 ***::['想了想不知道说什么，从技术到美学到设计，似乎在“勉强做成一个游戏”的范围内，在任何细微的角度去看都已经触及了最下限（完美的球对称性）。哪怕是这几年最令人发指的《宝可梦剑盾》，与之相比都过分可爱了起来。而有些玩家，则永远保持着不当韭菜天理难容的宽容。']==['Cuckoldoggy']::*** 10 ***::['这垃圾优化和满天的bug也敢拿出来卖？ 今年游戏界第二起消费欺诈行为']==['nesta']::*** 10 ***::['半成品拿来卖nm呢。bug不说，就当以后能修复。关键是宣传中许多东西根本没实现。']==['张小段']::*** 10 ***::['其他游戏公司出bug：垃圾游戏垃圾公司，滚吧，垃圾公司。\nCDPR 出bug：人不够没做完没办法，原谅它好吗？\n其他游戏公司虚假宣传：垃圾公司退款，再也不买再也不预购。祝游戏公司倒闭。\nCDPR虚假宣传：不跳票我们玩到就不错了，虚假宣传，不得已罢了。\n其他公司游戏打折：早知道不买了谁买谁上当。\nCDPR游戏打折：波兰蠢驴年度良心，我就让你赚钱。我们CDPR真是太厉害了，让我们在2020年年末玩到2077年的游戏。\nCDPR 孝子：你说他是fps？它不早就告诉你是RPG了。就知道跟风黑游戏，我看你都没玩过吧？又不是不会更新了，哪有什么虚假宣传，没做完罢了。开放世界？做不完没办法，毕竟才做了八年。\n我：孝死了。']==['ATReeves']::*** 0 ***::['越来越多的证据表明，这款游戏的发售日期并不是2077年。']==['Cole']::*** 40 ***::['  断断续续玩了三个月终于通了，总的来说感觉还是差点意思。兴许是刚开始抱着太高的期望再加上开头几天冲太猛了，后面一直没有什么动力继续玩下去。这两天终于在寒假倒计时的时候把主线支线都通了。其实对于关键的几个人物印象都还是比较深刻的，人物塑造的也都还不错。在最后每个人道别的时候，让我还是想再回去看他们一次，还是很爱他们每一个人。\n  总之希望后续dlc能好好做，毕竟当时抱了挺大的期望，还是希望夜之城能吸引我重新回到这座城市。\n  Goodbye, Night City and all my friends.\n  Hope to see you again.']==['Akira']::*** 30 ***::['很快啊']==['星子滑落夜空']::*** 0 ***::['仿生人会梦到赛博朋克2077吗？']==['司马农批']::*** 0 ***::['b社有天赋？是教子有方吗？']==['SquareOfSlow']::*** 0 ***::['我最喜欢这游戏的一点就是你如果不自己玩的话，在国内网络上几乎完全看不到这个游戏的真实模样是什么~']==['弹道学凝胶假人']::*** 30 ***::['期望越高，失望越大，等了8年就等来这\n除了画面和bug（这两点也不用细说了大家都有体验）；游戏性，沉浸感方面的问题更让人担忧，比如：\nNPC开车只会走直线，你把车停马路中间整条路就会堵死，因为NPC不会绕开，\n买义体改造连个动画都没有，跟在早点铺买包子没区别，\n说到早点铺，夜之城路边的商贩全都不能互动，\n阿sir是在玩家出现犯罪行为后直接生成的，过一会又会直接消失，\n当街开一枪，方圆两个街区所有路人整齐划一蹲下抱头等等等等…\n这就是CDPR口口声声宣传的“迄今为止沉浸感最强的开放世界”？\n目前感觉只有写好剧本的任务表现尚可，free roaming完全没意思\n索尼开始给2077数字版提供退款了，我已退款，游戏界曾经我最信任的开发商在我心里死了']==['HendersonYy']::*** 10 ***::['官方推荐配置1080p只要1066+16g，好家伙进去开全低30帧。诈骗呢？你家推荐配置是30帧玩游戏的？说清楚我就不会买。']==['流水不争先']::*** 10 ***::['还是血战上海滩好玩']==['糕等数学']::*** 0 ***::['我倒要看看到底有多好玩？']==['Neltharion.K']::*** 10 ***::['2020年游戏圈最大骗局，索尼下架，股票狂跌，大快人心！明明知道主机平台问题严重，在发售最后一天还在装模作样，宣发的时候都是PC演示，主机什么德性只有cdpr自己清楚！然后就满嘴谎话欺骗玩家，如果你们当时再把主机运行的承诺说的具体一点，就要被起诉欺诈了知道么']==['陈建宇Dede']::*** 20 ***::['是诈骗吧！bug多到不想打开 我就说我在酒吧下面坐了半天没等到朱迪吧 怎么了 2077年谈个恋爱还这么麻烦吗']==['叶湫忆']::*** 0 ***::['2077年，媒体公布最受期待游戏:《赛博朋克2077》《对马岛之鬼》《死亡搁浅》《骑砍2》《上古卷轴6》《半条命3》']==
# 0,40,10,10,10,10,10,0,40,30,0,0,0,30,10,10,0,10,20,0,
# ['0', '40', '10', '10', '10', '10', '10', '0', '40', '30', '0', '0', '0', '30', '10', '10', '0', '10', '20', '0']
# ['仿生人会梦见电子鸽吗', '那个把绀碧大厦当成妓院的人，你玩过游戏吗？', '修改为一星，为了基努不退款算对蠢驴客气了', '想了想不知道说什么，从技术到美学到设计，似乎在“勉强做成一个游戏”的范围内，在任何细微的角度去看都已经触及了最下限（完美的球对称性）。哪怕是这几年最令人发指的《宝可梦剑盾》，与之相比都过分可爱了起来。而有些玩家，则永远保持着不当韭菜天理难容的宽容。', '这垃圾优化和满天的bug也敢拿出来卖？ 今年游戏界第二起消费欺诈行为', '半成品拿来卖nm呢。bug不说，就当以后能修复。关键是宣传中许多东西根本没实现。', '其他游戏公司出bug：垃圾游戏垃圾公司，滚吧，垃圾公司。\\nCDPR 出bug：人不够没做完没办法，原谅它好吗？\\n其他游戏公司虚假宣传：垃圾公司退款，再也不买再也不预购。祝游戏公司倒闭。\\nCDPR虚假宣传：不跳票我们玩到就不错了，虚假宣传，不得已罢了。\\n其他公司游戏打折：早知道不买了谁买谁上当。\\nCDPR游戏打折：波兰蠢驴年度良心，我就让你赚钱。我们CDPR真是太厉害了，让我们在2020年年末玩到2077年的游戏。\\nCDPR 孝子：你说他是fps？它不早就告诉你是RPG了。就知道跟风黑游戏，我看你都没玩过吧？又不是不会更新了，哪有什么虚假宣传，没做完罢了。开放世界？做不完没办法，毕竟才做了八年。\\n我：孝死了。', '越来越多的证据表明，这款游戏的发售日期并不是2077年。', '  断断续续玩了三个月终于通了，总的来说感觉还是差点意思。兴许是刚开始抱着太高的期望再加上开头几天冲太猛了，后面一直没有什么动力继续玩下去。这两天终于在寒假倒计时的时候把主线支线都通了。其实对于关键的几个人物印象都还是比较深刻的，人物塑造的也都还不错。在最后每个人道别的时候，让我还是想再回去看他们一次，还是很爱他们每一个人。\\n  总之希望后续dlc能好好做，毕竟当时抱了挺大的期望，还是希望夜之城能吸引我重新回到这座城市。\\n  Goodbye, Night City and all my friends.\\n  Hope to see you again.', '很快啊', '仿生人会梦到赛博朋克2077吗？', 'b社有天赋？是教子有方吗？', '我最喜欢这游戏的一点就是你如果不自己玩的话，在国内网络上几乎完全看不到这个游戏的真实模样是什么~', '期望越高，失望越大，等了8年就等来这\\n除了画面和bug（这两点也不用细说了大家都有体验）；游戏性，沉浸感方面的问题更让人担忧，比如：\\nNPC开车只会走直线，你把车停马路中间整条路就会堵死，因为NPC不会绕开，\\n买义体改造连个动画都没有，跟在早点铺买包子没区别，\\n说到早点铺，夜之城路边的商贩全都不能互动，\\n阿sir是在玩家出现犯罪行为后直接生成的，过一会又会直接消失，\\n当街开一枪，方圆两个街区所有路人整齐划一蹲下抱头等等等等…\\n这就是CDPR口口声声宣传的“迄今为止沉浸感最强的开放世界”？\\n目前感觉只有写好剧本的任务表现尚可，free roaming完全没意思\\n索尼开始给2077数字版提供退款了，我已退款，游戏界曾经我最信任的开发商在我心里死了', '官方推荐配置1080p只要1066+16g，好家伙进去开全低30帧。诈骗呢？你家推荐配置是30帧玩游戏的？说清楚我就不会买。', '还是血战上海滩好玩', '我倒要看看到底有多好玩？', '2020年游戏圈最大骗局，索尼下架，股票狂跌，大快人心！明明知道主机平台问题严重，在发售最后一天还在装模作样，宣发的时候都是PC演示，主机什么德性只有cdpr自己清楚！然后就满嘴谎话欺骗玩家，如果你们当时再把主机运行的承诺说的具体一点，就要被起诉欺诈了知道么', '是诈骗吧！bug多到不想打开 我就说我在酒吧下面坐了半天没等到朱迪吧 怎么了 2077年谈个恋爱还这么麻烦吗', '2077年，媒体公布最受期待游戏:《赛博朋克2077》《对马岛之鬼》《死亡搁浅》《骑砍2》《上古卷轴6》《半条命3》']
# Counter({'10': 8, '0': 7, '40': 2, '30': 2, '20': 1})
# [7, 8, 1, 2, 2, 0]
# '/Users/momo/PycharmProjects/pythonProject1/mypie.html'

# %%
# 柱状图
from pyecharts.charts import Bar

bar = Bar()
bar.add_xaxis(["0分", "10分", "20分", "30分", "40分", "50分"])
bar.add_yaxis("赛博朋克 2077", [result[i] for i in sorted(result)])
#bar.render("mycharts.html")
bar.load_javascript()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7239a97876974a419040ce441015b1d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7239a97876974a419040ce441015b1d7 = echarts.init(
#                     document.getElementById('7239a97876974a419040ce441015b1d7'), 'white', {renderer: 'canvas'});
#                 var option_7239a97876974a419040ce441015b1d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8d5b\u535a\u670b\u514b 2077",
#             "legendHoverLink": true,
#             "data": [
#                 7,
#                 8,
#                 1,
#                 2,
#                 2,
#                 0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8d5b\u535a\u670b\u514b 2077"
#             ],
#             "selected": {
#                 "\u8d5b\u535a\u670b\u514b 2077": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5206",
#                 "10\u5206",
#                 "20\u5206",
#                 "30\u5206",
#                 "40\u5206",
#                 "50\u5206"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_7239a97876974a419040ce441015b1d7.setOption(option_7239a97876974a419040ce441015b1d7);
#         });
#     </script>
